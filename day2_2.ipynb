# %%
import numpy as np
import pandas as pd
df1=pd.DataFrame(np.random.rand(10,4),columns=('col1','col2','col3','col4'))

# %%
print(df1)
# Out:
#        col1      col2      col3      col4
# 0  0.051121  0.803997  0.316334  0.262246
# 1  0.593604  0.694665  0.815888  0.959201
# 2  0.078402  0.811062  0.795898  0.264469
# 3  0.562543  0.641006  0.517074  0.369570
# 4  0.215323  0.044801  0.043434  0.159365
# 5  0.968850  0.937486  0.159145  0.300022
# 6  0.078243  0.321462  0.786435  0.388763
# 7  0.635835  0.621391  0.460300  0.656778
# 8  0.580691  0.370841  0.242470  0.000461
# 9  0.140458  0.252927  0.449563  0.734565

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df1.plot(subplots=True,figsize=(8,8));

# %%
df1.plot(kind="hist");

# %%
df1.plot(kind="line");

# %%
df1.plot(kind="bar");

# %%
df1.plot(kind="barh");

# %%
df1.plot(kind="box");

# %%
df1.plot(kind="kde");

# %%
df1.plot(kind="density");

# %%
df1.plot(kind="area");

# %%
df1.plot(kind="pie", y="col1");

# %%
df1.plot(kind="scatter",x='col1',y='col2');

# %%
df1.plot(kind="hexbin",x='col1',y='col2');
